# %%
# Importing all the necessary libraries
# Data wrangling modules
import pandas as pd
import numpy as np

# Suppressing warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)

# %%
pd.options.display.float_format = '{:,.3f}'.format

# %%
df_allchannelsalesvol = pd.read_excel('Salesvol-Combined - Copy.xlsx')

# %%
df_allchannelsalesunits = pd.read_excel('Salesunit-Combined.xlsx')

# %% [markdown]
# Skus	Out of Stock	Low WOS
# SPF35 Travel Size	YES
# Skin Mist Full Size	YES
# Eye Cream	YES
# Serum-Eye	YES
# Ritual Starter Sets (.com)	NO	Yes

# %%
df_allchannelsalesvol.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236415 entries, 0 to 236414
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236415 non-null  int64
#  1   Month           236415 non-null  int64
#  2   Record Date     236415 non-null  datetime64[ns]
#  3   Sku #           204025 non-null  object
#  4   Sku             236415 non-null  object
#  5   Merged Sku      236415 non-null  object
#  6   Launch Date     204025 non-null  float64
#  7   Classification  204025 non-null  object
#  8   Subclass        204025 non-null  object
#  9   Collection      204025 non-null  object
#  10  Channel         236415 non-null  int64
#  11  Volume          236415 non-null  float64
#  12  COGS            204025 non-null  float64
#  13  MSRP            204025 non-null  float64
#  14  Line Edit       204025 non-null  object
#  15  Region Name     204025 non-null  object
# ...

# %%
df_allchannelsalesunits.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236532 entries, 0 to 236531
# Data columns (total 16 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Year            236532 non-null  int64
#  1   Month           236532 non-null  int64
#  2   Record Date     236532 non-null  datetime64[ns]
#  3   Sku #           204138 non-null  object
#  4   Sku             236532 non-null  object
#  5   Merged Sku      236508 non-null  object
#  6   Launch Date     204138 non-null  float64
#  7   Classification  204138 non-null  object
#  8   Subclass        204138 non-null  object
#  9   Collection      204138 non-null  object
#  10  Channel         236532 non-null  int64
#  11  Units           236532 non-null  float64
#  12  COGS            204138 non-null  float64
#  13  MSRP            204138 non-null  float64
#  14  Line Edit       204138 non-null  object
#  15  Region Name     204138 non-null  object
# ...

# %%
net_revenue = df_allchannelsalesvol['Volume'].sum()

# %%
net_revenue
# Out:
# 1290733317.437273

# %%
net_sales = df_allchannelsalesunits['Units'].sum()

# %%
net_sales
# Out:
# 26232097.617269002

# %%
spf35_filt = (df_allchannelsalesvol['Sku'].str.contains('SPF35')) & (df_allchannelsalesvol['Sku'].str.contains('TRAVEL'))
df_allchannelsalesvol[spf35_filt]
# Out:
#         Year  Month Record Date   Sku #                    Sku    Merged Sku  \
# 11628   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11629   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11630   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11631   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11632   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# ...      ...    ...         ...     ...                    ...           ...
# 232198  2019      8  2019-08-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 232199  2019      9  2019-09-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 232200  2019     10  2019-10-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 232201  2019     11  2019-11-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 232202  2019     12  2019-12-01     NaN  TSN-SPF35-TRAVEL-GIFT
#
#         Launch Date Classification Subclass Collection  Channel  Volume  COGS  \
# ...

# %%
df_allchannelsalesvol['Volume'][spf35_filt].sum()
# Out:
# 1168368.0

# %%
(df_allchannelsalesvol['Volume'][spf35_filt].sum()/net_revenue)*100
# Out:
# 0.09051970567551265

# %%
spf35_filt_units = (df_allchannelsalesunits['Sku'].str.contains('SPF35')) & (df_allchannelsalesunits['Sku'].str.contains('TRAVEL'))
df_allchannelsalesunits[spf35_filt_units]
# Out:
#         Year  Month Record Date   Sku #                    Sku    Merged Sku  \
# 11628   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11629   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11630   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11631   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# 11632   2017      1  2017-01-01  Sku 82           SPF35-TRAVEL  SPF35-TRAVEL
# ...      ...    ...         ...     ...                    ...           ...
# 226933  2019      8  2019-08-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 226934  2019      9  2019-09-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 226935  2019     10  2019-10-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 226936  2019     11  2019-11-01     NaN  TSN-SPF35-TRAVEL-GIFT
# 226937  2019     12  2019-12-01     NaN  TSN-SPF35-TRAVEL-GIFT
#
#         Launch Date Classification Subclass Collection  Channel  Units  COGS  \
# ...

# %%
df_allchannelsalesunits['Units'][spf35_filt_units].sum()
# Out:
# 78803.0

# %%
serum_eye_sales = df_allchannelsalesunits['Units'][spf35_filt_units].sum()
print((serum_eye_sales*100)/net_sales)
# Out:
# 0.30040678084440625

# %%
df_allchannelsalesvol[df_allchannelsalesvol['Sku'].str.contains('SKIN-MIST')]
# Out:
# Empty DataFrame
# Columns: [Year, Month, Record Date, Sku #, Sku, Merged Sku, Launch Date, Classification, Subclass, Collection, Channel, Volume, COGS, MSRP, Line Edit, Region Name]
# Index: []

# %%
df_allchannelsalesvol['Volume'][df_allchannelsalesvol['Sku'].str.contains('SKIN-MIST')].sum()
# Out:
# 100839799.91603296

# %%
(df_allchannelsalesvol['Volume'][df_allchannelsalesvol['Sku'].str.contains('SKIN-MIST')].sum()/net_revenue)*100
# Out:
# 7.812597579509957

# %%
df_allchannelsalesunits[df_allchannelsalesunits['Sku'].str.contains('SKIN-MIST')]
# Out:
#         Year  Month Record Date   Sku #                  Sku  \
# 9804    2017      1  2017-01-01     NaN   RTR-SKIN-MIST-LE17
# 9805    2017      2  2017-02-01     NaN   RTR-SKIN-MIST-LE17
# 9806    2017      3  2017-03-01     NaN   RTR-SKIN-MIST-LE17
# 9807    2017      4  2017-04-01     NaN   RTR-SKIN-MIST-LE17
# 9808    2017      5  2017-05-01     NaN   RTR-SKIN-MIST-LE17
# ...      ...    ...         ...     ...                  ...
# 236455  2019     11  2019-11-01  Sku 19  SKIN-MIST-TRAVEL-V2
# 236456  2019     11  2019-11-01  Sku 19  SKIN-MIST-TRAVEL-V2
# 236457  2019     12  2019-12-01  Sku 19  SKIN-MIST-TRAVEL-V2
# 236458  2019     12  2019-12-01  Sku 19  SKIN-MIST-TRAVEL-V2
# 236459  2019     12  2019-12-01  Sku 19  SKIN-MIST-TRAVEL-V2
#
#                  Merged Sku  Launch Date Classification Subclass Collection  \
# 9804     RTR-SKIN-MIST-LE17          NaN            NaN      NaN        NaN
# 9805     RTR-SKIN-MIST-LE17          NaN            NaN      NaN        NaN
# ...

# %%
df_allchannelsalesunits['Units'][df_allchannelsalesunits['Sku'].str.contains('SKIN-MIST')].sum()
# Out:
# 2706651.942366827

# %%
serum_eye_sales = df_allchannelsalesunits['Units'][df_allchannelsalesunits['Sku'].str.contains('SKIN-MIST')].sum()
print((serum_eye_sales*100)/net_sales)
# Out:
# 10.318091911128736

# %%
df_allchannelsalesvol[df_allchannelsalesvol['Sku'].str.contains('EYE-CREAM')]
# Out:
#         Year  Month Record Date   Sku #                        Sku Merged Sku  \
# 2880    2017      1  2017-01-01  Sku 46                  EYE-CREAM  EYE-CREAM
# 2881    2017      1  2017-01-01  Sku 46                  EYE-CREAM  EYE-CREAM
# 2882    2017      1  2017-01-01  Sku 46                  EYE-CREAM  EYE-CREAM
# 2883    2017      1  2017-01-01  Sku 46                  EYE-CREAM  EYE-CREAM
# 2884    2017      1  2017-01-01  Sku 46                  EYE-CREAM  EYE-CREAM
# ...      ...    ...         ...     ...                        ...        ...
# 232078  2019      8  2019-08-01     NaN  TSN-EYE-CREAM-TRAVEL-COMP
# 232079  2019      9  2019-09-01     NaN  TSN-EYE-CREAM-TRAVEL-COMP
# 232080  2019     10  2019-10-01     NaN  TSN-EYE-CREAM-TRAVEL-COMP
# 232081  2019     11  2019-11-01     NaN  TSN-EYE-CREAM-TRAVEL-COMP
# 232082  2019     12  2019-12-01     NaN  TSN-EYE-CREAM-TRAVEL-COMP
#
#         Launch Date Classification Subclass Collection  Channel  Volume  COGS  \
# ...

# %%
df_allchannelsalesvol['Volume'][df_allchannelsalesvol['Sku'].str.contains('EYE-CREAM')].sum()
# Out:
# 10379024.161849711

# %%
(df_allchannelsalesvol['Volume'][df_allchannelsalesvol['Sku'].str.contains('EYE-CREAM')].sum()/net_revenue)*100
# Out:
# 0.8041184047574654

# %%
df_allchannelsalesunits[df_allchannelsalesunits['Sku'].str.contains('EYE-CREAM')]
# Out:
#         Year  Month Record Date   Sku #        Sku Merged Sku  Launch Date  \
# 2880    2017      1  2017-01-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 2881    2017      1  2017-01-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 2882    2017      1  2017-01-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 2883    2017      1  2017-01-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 2884    2017      1  2017-01-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# ...      ...    ...         ...     ...        ...        ...          ...
# 234331  2019     12  2019-12-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 234332  2019     12  2019-12-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 234333  2019     12  2019-12-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 234334  2019     12  2019-12-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
# 234335  2019     12  2019-12-01  Sku 46  EYE-CREAM  EYE-CREAM    2,016.000
#
# ...

# %%
df_allchannelsalesunits['Units'][df_allchannelsalesunits['Sku'].str.contains('EYE-CREAM')].sum()
# Out:
# 185436.0

# %%
serum_eye_sales = df_allchannelsalesunits['Units'][df_allchannelsalesunits['Sku'].str.contains('EYE-CREAM')].sum()
print((serum_eye_sales*100)/net_sales)
# Out:
# 0.7069049631697183

# %% [markdown]
# **Serum-Eye**

# %%
df_allchannelsalesvol[df_allchannelsalesvol['Sku'].str.contains('SERUM-EYE')]
# Out:
#         Year  Month Record Date   Sku #                        Sku Merged Sku  \
# 10236   2017      1  2017-01-01  Sku 22                  SERUM-EYE  SERUM-EYE
# 10237   2017      1  2017-01-01  Sku 22                  SERUM-EYE  SERUM-EYE
# 10238   2017      1  2017-01-01  Sku 22                  SERUM-EYE  SERUM-EYE
# 10239   2017      1  2017-01-01  Sku 22                  SERUM-EYE  SERUM-EYE
# 10240   2017      1  2017-01-01  Sku 22                  SERUM-EYE  SERUM-EYE
# ...      ...    ...         ...     ...                        ...        ...
# 232162  2019      8  2019-08-01     NaN  TSN-SERUM-EYE-TRAVEL-GIFT
# 232163  2019      9  2019-09-01     NaN  TSN-SERUM-EYE-TRAVEL-GIFT
# 232164  2019     10  2019-10-01     NaN  TSN-SERUM-EYE-TRAVEL-GIFT
# 232165  2019     11  2019-11-01     NaN  TSN-SERUM-EYE-TRAVEL-GIFT
# 232166  2019     12  2019-12-01     NaN  TSN-SERUM-EYE-TRAVEL-GIFT
#
#         Launch Date Classification Subclass Collection  Channel  Volume  COGS  \
# ...

# %%
df_allchannelsalesvol['Volume'][df_allchannelsalesvol['Sku'].str.contains('SERUM-EYE')].sum()
# Out:
# 21968469.63559559

# %%
(df_allchannelsalesvol['Volume'][df_allchannelsalesvol['Sku'].str.contains('SERUM-EYE')].sum()/net_revenue)*100
# Out:
# 1.7020146097424353

# %%
df_allchannelsalesunits[df_allchannelsalesunits['Sku'].str.contains('SERUM-EYE')]
# Out:
#         Year  Month Record Date   Sku #        Sku Merged Sku  Launch Date  \
# 10236   2017      1  2017-01-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 10237   2017      1  2017-01-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 10238   2017      1  2017-01-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 10239   2017      1  2017-01-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 10240   2017      1  2017-01-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# ...      ...    ...         ...     ...        ...        ...          ...
# 234067  2019     12  2019-12-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 234068  2019     12  2019-12-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 234069  2019     12  2019-12-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 234070  2019     12  2019-12-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
# 234071  2019     12  2019-12-01  Sku 22  SERUM-EYE  SERUM-EYE    2,016.000
#
# ...

# %%
df_allchannelsalesunits['Units'][df_allchannelsalesunits['Sku'].str.contains('SERUM-EYE')].sum()
# Out:
# 281389.053773684

# %%
serum_eye_sales = df_allchannelsalesunits['Units'][df_allchannelsalesunits['Sku'].str.contains('SERUM-EYE')].sum()
print((serum_eye_sales*100)/net_sales)
# Out:
# 1.0726898697892966

# %% [markdown]
# **Ritual-Starter-Set**

# %%
filt = (df_allchannelsalesvol['Sku'].str.contains('RITUAL')) & (df_allchannelsalesvol['Sku'].str.contains('STARTER'))
df_allchannelsalesvol[filt]
# Out:
#         Year  Month Record Date   Sku #                  Sku  \
# 154935  2018      1  2018-01-01  Sku 57  BLUE-STARTER-RITUAL
# 154936  2018      2  2018-02-01  Sku 57  BLUE-STARTER-RITUAL
# 154937  2018      3  2018-03-01  Sku 57  BLUE-STARTER-RITUAL
# 154938  2018      4  2018-04-01  Sku 57  BLUE-STARTER-RITUAL
# 154939  2018      5  2018-05-01  Sku 57  BLUE-STARTER-RITUAL
# ...      ...    ...         ...     ...                  ...
# 236266  2019      8  2019-08-01  Sku 58  DEWY-STARTER-RITUAL
# 236267  2019      9  2019-09-01  Sku 58  DEWY-STARTER-RITUAL
# 236268  2019     10  2019-10-01  Sku 58  DEWY-STARTER-RITUAL
# 236269  2019     11  2019-11-01  Sku 58  DEWY-STARTER-RITUAL
# 236270  2019     12  2019-12-01  Sku 58  DEWY-STARTER-RITUAL
#
#                  Merged Sku  Launch Date Classification Subclass Collection  \
# 154935  BLUE-STARTER-RITUAL    2,018.000       Core Set      Set       RDKs
# 154936  BLUE-STARTER-RITUAL    2,018.000       Core Set      Set       RDKs
# ...

# %%
df_allchannelsalesvol['Volume'][filt].sum()
# Out:
# 1827702.0

# %%
(df_allchannelsalesvol['Volume'][filt].sum()*100)/net_revenue
# Out:
# 0.14160183016185468

# %%
filt = (df_allchannelsalesunits['Sku'].str.contains('RITUAL')) & (df_allchannelsalesunits['Sku'].str.contains('STARTER'))
df_allchannelsalesunits[filt]
# Out:
#         Year  Month Record Date   Sku #                  Sku  \
# 213966  2018      1  2018-01-01  Sku 57  BLUE-STARTER-RITUAL
# 213967  2018      2  2018-02-01  Sku 57  BLUE-STARTER-RITUAL
# 213968  2018      3  2018-03-01  Sku 57  BLUE-STARTER-RITUAL
# 213969  2018      4  2018-04-01  Sku 57  BLUE-STARTER-RITUAL
# 213970  2018      5  2018-05-01  Sku 57  BLUE-STARTER-RITUAL
# ...      ...    ...         ...     ...                  ...
# 231001  2019      8  2019-08-01  Sku 58  DEWY-STARTER-RITUAL
# 231002  2019      9  2019-09-01  Sku 58  DEWY-STARTER-RITUAL
# 231003  2019     10  2019-10-01  Sku 58  DEWY-STARTER-RITUAL
# 231004  2019     11  2019-11-01  Sku 58  DEWY-STARTER-RITUAL
# 231005  2019     12  2019-12-01  Sku 58  DEWY-STARTER-RITUAL
#
#                  Merged Sku  Launch Date Classification Subclass Collection  \
# 213966  BLUE-STARTER-RITUAL    2,018.000       Core Set      Set       RDKs
# 213967  BLUE-STARTER-RITUAL    2,018.000       Core Set      Set       RDKs
# ...

# %%
df_allchannelsalesunits['Units'][filt].sum()
# Out:
# 30983.0

# %%
(df_allchannelsalesunits['Units'][filt].sum()*100)/net_sales
# Out:
# 0.11811102738350365

# %%
Skus	Out of Stock	Low WOS
SPF35 Travel Size	YES	
Skin Mist Full Size	YES	
Eye Cream	YES	
Serum-Eye	YES	
Ritual Starter Sets (.com)	NO	Yes

# %%
inventory_data = [
    ['SPF35 Travel Size', 1, 0, 0.09051, 0.30040],
    ['Skin Mist Full Size', 1, 0, 7.81259, 10.31809],
    ['Eye Cream', 1, 0, 0.80411, 0.70690],
    ['Serum-Eye', 1, 0, 1.70201, 1.07268],
    ['Ritual Starter Sets (.com)', 0, 1, 0.14160, 0.11811]
]

# %%
inventory = pd.DataFrame(inventory_data, columns=['SKUs', 'Out-of-Stock', 'Low-On-Stock', '%Revenue Contribution', '%Sales Contribution'])

# %%
inventory
# Out:
#                          SKUs  Out-of-Stock  Low-On-Stock  \
# 0           SPF35 Travel Size             1             0
# 1         Skin Mist Full Size             1             0
# 2                   Eye Cream             1             0
# 3                   Serum-Eye             1             0
# 4  Ritual Starter Sets (.com)             0             1
#
#    %Revenue Contribution  %Sales Contribution
# 0                  0.091                0.300
# 1                  7.813               10.318
# 2                  0.804                0.707
# 3                  1.702                1.073
# 4                  0.142                0.118
